# %%
import random
import time

# Initialize battery pack with 8 cells, each with a charge level between 80-100%
battery_pack = [random.uniform(80, 100) for _ in range(8)]
min_charge = 20   # Minimum charge threshold to trigger switch
charge_rate = 5   # Charge rate per cycle
discharge_rate = 10  # Discharge rate per cycle

def discharge_group(group):
    """Discharge the active group cells."""
    for i in group:
        battery_pack[i] = max(0, battery_pack[i] - discharge_rate)

def charge_group(group):
    """Charge the resting group cells."""
    for i in group:
        battery_pack[i] = min(100, battery_pack[i] + charge_rate)

def switch_groups(active_group, resting_group):
    """Switch active and resting groups."""
    return resting_group, active_group

def display_battery_status():
    """Print the current battery status of all cells."""
    status = " | ".join(f"Cell {i+1}: {battery_pack[i]:.1f}%" for i in range(8))
    print(f"[Battery Status] {status}")

# Initial groups
active_group = [0, 1, 2, 3]
resting_group = [4, 5, 6, 7]

# Simulation loop
for cycle in range(1, 11):  # Run 10 cycles for simulation
    print(f"\n[Cycle {cycle}]")
    display_battery_status()

    # Discharge active group and charge resting group
    print("Discharging active group and charging resting group...")
    discharge_group(active_group)
    charge_group(resting_group)

    # Check if any active cell is below the threshold
    if any(battery_pack[i] <= min_charge for i in active_group):
        print("Switching groups due to low charge in active cells.")
        active_group, resting_group = switch_groups(active_group, resting_group)

    # Short delay to simulate real-time processing (remove for faster testing)
    time.sleep(1)

print("\n[Final Battery Status]")
display_battery_status()
# Out:
# [Cycle 1]
# [Battery Status] Cell 1: 99.8% | Cell 2: 82.8% | Cell 3: 84.0% | Cell 4: 91.3% | Cell 5: 83.6% | Cell 6: 90.9% | Cell 7: 98.5% | Cell 8: 99.4%
# Discharging active group and charging resting group...
#
# [Cycle 2]
# [Battery Status] Cell 1: 89.8% | Cell 2: 72.8% | Cell 3: 74.0% | Cell 4: 81.3% | Cell 5: 88.6% | Cell 6: 95.9% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 3]
# [Battery Status] Cell 1: 79.8% | Cell 2: 62.8% | Cell 3: 64.0% | Cell 4: 71.3% | Cell 5: 93.6% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 4]
# [Battery Status] Cell 1: 69.8% | Cell 2: 52.8% | Cell 3: 54.0% | Cell 4: 61.3% | Cell 5: 98.6% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 5]
# [Battery Status] Cell 1: 59.8% | Cell 2: 42.8% | Cell 3: 44.0% | Cell 4: 51.3% | Cell 5: 100.0% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 6]
# [Battery Status] Cell 1: 49.8% | Cell 2: 32.8% | Cell 3: 34.0% | Cell 4: 41.3% | Cell 5: 100.0% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 7]
# [Battery Status] Cell 1: 39.8% | Cell 2: 22.8% | Cell 3: 24.0% | Cell 4: 31.3% | Cell 5: 100.0% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
# Switching groups due to low charge in active cells.
#
# [Cycle 8]
# [Battery Status] Cell 1: 29.8% | Cell 2: 12.8% | Cell 3: 14.0% | Cell 4: 21.3% | Cell 5: 100.0% | Cell 6: 100.0% | Cell 7: 100.0% | Cell 8: 100.0%
# Discharging active group and charging resting group...
#
# [Cycle 9]
# [Battery Status] Cell 1: 34.8% | Cell 2: 17.8% | Cell 3: 19.0% | Cell 4: 26.3% | Cell 5: 90.0% | Cell 6: 90.0% | Cell 7: 90.0% | Cell 8: 90.0%
# Discharging active group and charging resting group...
#
# [Cycle 10]
# [Battery Status] Cell 1: 39.8% | Cell 2: 22.8% | Cell 3: 24.0% | Cell 4: 31.3% | Cell 5: 80.0% | Cell 6: 80.0% | Cell 7: 80.0% | Cell 8: 80.0%
# Discharging active group and charging resting group...
#
# [Final Battery Status]
# [Battery Status] Cell 1: 44.8% | Cell 2: 27.8% | Cell 3: 29.0% | Cell 4: 36.3% | Cell 5: 70.0% | Cell 6: 70.0% | Cell 7: 70.0% | Cell 8: 70.0%

# %%
import random
import time

# Initialize battery pack with 8 cells, each with a charge level between 80-100%
battery_pack = [random.uniform(80, 100) for _ in range(8)]
min_charge = 20    # Minimum charge threshold to trigger group reshuffling
charge_rate = 5    # Charge rate per cycle
discharge_rate = 10  # Discharge rate per cycle

def discharge_group(group):
    """Discharge the active group cells."""
    for i in group:
        battery_pack[i] = max(0, battery_pack[i] - discharge_rate)

def charge_group(group):
    """Charge the resting group cells."""
    for i in group:
        battery_pack[i] = min(100, battery_pack[i] + charge_rate)

def select_groups():
    """Select cells dynamically based on current charge levels."""
    # Sort cells by charge level (descending) and get their indices
    sorted_cells = sorted(range(len(battery_pack)), key=lambda i: battery_pack[i], reverse=True)

    # Top 4 cells with the highest charge go to active group
    active_group = sorted_cells[:4]

    # Remaining 4 cells go to resting group
    resting_group = sorted_cells[4:]

    return active_group, resting_group

def display_battery_status():
    """Print the current battery status of all cells."""
    status = " | ".join(f"Cell {i+1}: {battery_pack[i]:.1f}%" for i in range(8))
    print(f"[Battery Status] {status}")

# Simulation loop
for cycle in range(1, 51):  # Run n cycles for simulation
    print(f"\n[Cycle {cycle}]")
    display_battery_status()

    # Dynamically select active and resting groups
    active_group, resting_group = select_groups()
    print(f"Selected Active Group: {[i+1 for i in active_group]}")
    print(f"Selected Resting Group: {[i+1 for i in resting_group]}")

    # Discharge active group and charge resting group
    print("Discharging active group and charging resting group...")
    discharge_group(active_group)
    charge_group(resting_group)

    # Short delay to simulate real-time processing (remove for faster testing)
    time.sleep(1)

print("\n[Final Battery Status]")
display_battery_status()
# Out:
# [Cycle 1]
# [Battery Status] Cell 1: 83.5% | Cell 2: 84.3% | Cell 3: 90.4% | Cell 4: 95.6% | Cell 5: 98.0% | Cell 6: 86.1% | Cell 7: 83.2% | Cell 8: 87.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 2]
# [Battery Status] Cell 1: 88.5% | Cell 2: 89.3% | Cell 3: 80.4% | Cell 4: 85.6% | Cell 5: 88.0% | Cell 6: 91.1% | Cell 7: 88.2% | Cell 8: 77.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 3]
# [Battery Status] Cell 1: 78.5% | Cell 2: 79.3% | Cell 3: 85.4% | Cell 4: 90.6% | Cell 5: 93.0% | Cell 6: 81.1% | Cell 7: 78.2% | Cell 8: 82.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 4]
# [Battery Status] Cell 1: 83.5% | Cell 2: 84.3% | Cell 3: 75.4% | Cell 4: 80.6% | Cell 5: 83.0% | Cell 6: 86.1% | Cell 7: 83.2% | Cell 8: 72.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 5]
# [Battery Status] Cell 1: 73.5% | Cell 2: 74.3% | Cell 3: 80.4% | Cell 4: 85.6% | Cell 5: 88.0% | Cell 6: 76.1% | Cell 7: 73.2% | Cell 8: 77.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 6]
# [Battery Status] Cell 1: 78.5% | Cell 2: 79.3% | Cell 3: 70.4% | Cell 4: 75.6% | Cell 5: 78.0% | Cell 6: 81.1% | Cell 7: 78.2% | Cell 8: 67.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 7]
# [Battery Status] Cell 1: 68.5% | Cell 2: 69.3% | Cell 3: 75.4% | Cell 4: 80.6% | Cell 5: 83.0% | Cell 6: 71.1% | Cell 7: 68.2% | Cell 8: 72.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 8]
# [Battery Status] Cell 1: 73.5% | Cell 2: 74.3% | Cell 3: 65.4% | Cell 4: 70.6% | Cell 5: 73.0% | Cell 6: 76.1% | Cell 7: 73.2% | Cell 8: 62.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 9]
# [Battery Status] Cell 1: 63.5% | Cell 2: 64.3% | Cell 3: 70.4% | Cell 4: 75.6% | Cell 5: 78.0% | Cell 6: 66.1% | Cell 7: 63.2% | Cell 8: 67.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 10]
# [Battery Status] Cell 1: 68.5% | Cell 2: 69.3% | Cell 3: 60.4% | Cell 4: 65.6% | Cell 5: 68.0% | Cell 6: 71.1% | Cell 7: 68.2% | Cell 8: 57.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 11]
# [Battery Status] Cell 1: 58.5% | Cell 2: 59.3% | Cell 3: 65.4% | Cell 4: 70.6% | Cell 5: 73.0% | Cell 6: 61.1% | Cell 7: 58.2% | Cell 8: 62.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 12]
# [Battery Status] Cell 1: 63.5% | Cell 2: 64.3% | Cell 3: 55.4% | Cell 4: 60.6% | Cell 5: 63.0% | Cell 6: 66.1% | Cell 7: 63.2% | Cell 8: 52.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 13]
# [Battery Status] Cell 1: 53.5% | Cell 2: 54.3% | Cell 3: 60.4% | Cell 4: 65.6% | Cell 5: 68.0% | Cell 6: 56.1% | Cell 7: 53.2% | Cell 8: 57.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 14]
# [Battery Status] Cell 1: 58.5% | Cell 2: 59.3% | Cell 3: 50.4% | Cell 4: 55.6% | Cell 5: 58.0% | Cell 6: 61.1% | Cell 7: 58.2% | Cell 8: 47.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 15]
# [Battery Status] Cell 1: 48.5% | Cell 2: 49.3% | Cell 3: 55.4% | Cell 4: 60.6% | Cell 5: 63.0% | Cell 6: 51.1% | Cell 7: 48.2% | Cell 8: 52.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 16]
# [Battery Status] Cell 1: 53.5% | Cell 2: 54.3% | Cell 3: 45.4% | Cell 4: 50.6% | Cell 5: 53.0% | Cell 6: 56.1% | Cell 7: 53.2% | Cell 8: 42.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 17]
# [Battery Status] Cell 1: 43.5% | Cell 2: 44.3% | Cell 3: 50.4% | Cell 4: 55.6% | Cell 5: 58.0% | Cell 6: 46.1% | Cell 7: 43.2% | Cell 8: 47.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 18]
# [Battery Status] Cell 1: 48.5% | Cell 2: 49.3% | Cell 3: 40.4% | Cell 4: 45.6% | Cell 5: 48.0% | Cell 6: 51.1% | Cell 7: 48.2% | Cell 8: 37.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 19]
# [Battery Status] Cell 1: 38.5% | Cell 2: 39.3% | Cell 3: 45.4% | Cell 4: 50.6% | Cell 5: 53.0% | Cell 6: 41.1% | Cell 7: 38.2% | Cell 8: 42.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 20]
# [Battery Status] Cell 1: 43.5% | Cell 2: 44.3% | Cell 3: 35.4% | Cell 4: 40.6% | Cell 5: 43.0% | Cell 6: 46.1% | Cell 7: 43.2% | Cell 8: 32.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 21]
# [Battery Status] Cell 1: 33.5% | Cell 2: 34.3% | Cell 3: 40.4% | Cell 4: 45.6% | Cell 5: 48.0% | Cell 6: 36.1% | Cell 7: 33.2% | Cell 8: 37.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 22]
# [Battery Status] Cell 1: 38.5% | Cell 2: 39.3% | Cell 3: 30.4% | Cell 4: 35.6% | Cell 5: 38.0% | Cell 6: 41.1% | Cell 7: 38.2% | Cell 8: 27.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 23]
# [Battery Status] Cell 1: 28.5% | Cell 2: 29.3% | Cell 3: 35.4% | Cell 4: 40.6% | Cell 5: 43.0% | Cell 6: 31.1% | Cell 7: 28.2% | Cell 8: 32.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 24]
# [Battery Status] Cell 1: 33.5% | Cell 2: 34.3% | Cell 3: 25.4% | Cell 4: 30.6% | Cell 5: 33.0% | Cell 6: 36.1% | Cell 7: 33.2% | Cell 8: 22.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 25]
# [Battery Status] Cell 1: 23.5% | Cell 2: 24.3% | Cell 3: 30.4% | Cell 4: 35.6% | Cell 5: 38.0% | Cell 6: 26.1% | Cell 7: 23.2% | Cell 8: 27.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 26]
# [Battery Status] Cell 1: 28.5% | Cell 2: 29.3% | Cell 3: 20.4% | Cell 4: 25.6% | Cell 5: 28.0% | Cell 6: 31.1% | Cell 7: 28.2% | Cell 8: 17.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 27]
# [Battery Status] Cell 1: 18.5% | Cell 2: 19.3% | Cell 3: 25.4% | Cell 4: 30.6% | Cell 5: 33.0% | Cell 6: 21.1% | Cell 7: 18.2% | Cell 8: 22.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 28]
# [Battery Status] Cell 1: 23.5% | Cell 2: 24.3% | Cell 3: 15.4% | Cell 4: 20.6% | Cell 5: 23.0% | Cell 6: 26.1% | Cell 7: 23.2% | Cell 8: 12.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 29]
# [Battery Status] Cell 1: 13.5% | Cell 2: 14.3% | Cell 3: 20.4% | Cell 4: 25.6% | Cell 5: 28.0% | Cell 6: 16.1% | Cell 7: 13.2% | Cell 8: 17.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 30]
# [Battery Status] Cell 1: 18.5% | Cell 2: 19.3% | Cell 3: 10.4% | Cell 4: 15.6% | Cell 5: 18.0% | Cell 6: 21.1% | Cell 7: 18.2% | Cell 8: 7.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 31]
# [Battery Status] Cell 1: 8.5% | Cell 2: 9.3% | Cell 3: 15.4% | Cell 4: 20.6% | Cell 5: 23.0% | Cell 6: 11.1% | Cell 7: 8.2% | Cell 8: 12.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 32]
# [Battery Status] Cell 1: 13.5% | Cell 2: 14.3% | Cell 3: 5.4% | Cell 4: 10.6% | Cell 5: 13.0% | Cell 6: 16.1% | Cell 7: 13.2% | Cell 8: 2.6%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 33]
# [Battery Status] Cell 1: 3.5% | Cell 2: 4.3% | Cell 3: 10.4% | Cell 4: 15.6% | Cell 5: 18.0% | Cell 6: 6.1% | Cell 7: 3.2% | Cell 8: 7.6%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 2, 1, 7]
# Discharging active group and charging resting group...
#
# [Cycle 34]
# [Battery Status] Cell 1: 8.5% | Cell 2: 9.3% | Cell 3: 0.4% | Cell 4: 5.6% | Cell 5: 8.0% | Cell 6: 11.1% | Cell 7: 8.2% | Cell 8: 0.0%
# Selected Active Group: [6, 2, 1, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 35]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.4% | Cell 4: 10.6% | Cell 5: 13.0% | Cell 6: 1.1% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [6, 1, 2, 7]
# Discharging active group and charging resting group...
#
# [Cycle 36]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.6% | Cell 5: 3.0% | Cell 6: 6.1% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [6, 1, 2, 7]
# Selected Resting Group: [5, 4, 3, 8]
# Discharging active group and charging resting group...
#
# [Cycle 37]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.6% | Cell 5: 8.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [5, 4, 3, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 38]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 39]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 40]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 41]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 42]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 43]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 44]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 45]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 46]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 47]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 48]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Cycle 49]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%
# Selected Active Group: [3, 4, 5, 8]
# Selected Resting Group: [1, 2, 6, 7]
# Discharging active group and charging resting group...
#
# [Cycle 50]
# [Battery Status] Cell 1: 5.0% | Cell 2: 5.0% | Cell 3: 0.0% | Cell 4: 0.0% | Cell 5: 0.0% | Cell 6: 5.0% | Cell 7: 5.0% | Cell 8: 0.0%
# Selected Active Group: [1, 2, 6, 7]
# Selected Resting Group: [3, 4, 5, 8]
# Discharging active group and charging resting group...
#
# [Final Battery Status]
# [Battery Status] Cell 1: 0.0% | Cell 2: 0.0% | Cell 3: 5.0% | Cell 4: 5.0% | Cell 5: 5.0% | Cell 6: 0.0% | Cell 7: 0.0% | Cell 8: 5.0%

# %%
import random
import time

# Initialize battery pack with 8 cells, each with a charge level between 80-100%
battery_pack = [random.uniform(80, 100) for _ in range(8)]
min_charge = 20      # Minimum charge threshold to trigger group reshuffling
charge_rate = 5      # Charge rate per cycle
base_discharge_rate = 10  # Base discharge rate per cycle

# Define range factors (in km) for different levels of power demand
range_factors = {
    'low': 1.5,     # Low power demand (e.g., steady city driving)
    'medium': 1.0,  # Moderate power demand (e.g., highway driving)
    'high': 0.5     # High power demand (e.g., uphill or acceleration)
}

# Select a range factor for the simulation
current_range_factor = range_factors['medium']  # Choose based on scenario

def discharge_group(group):
    """Discharge the active group cells based on the range factor."""
    # Adjust discharge rate based on the selected range factor
    discharge_rate = base_discharge_rate / current_range_factor
    for i in group:
        battery_pack[i] = max(0, battery_pack[i] - discharge_rate)

def charge_group(group):
    """Charge the resting group cells."""
    for i in group:
        battery_pack[i] = min(100, battery_pack[i] + charge_rate)

def select_groups():
    """Select cells dynamically based on current charge levels."""
    # Sort cells by charge level (descending) and get their indices
    sorted_cells = sorted(range(len(battery_pack)), key=lambda i: battery_pack[i], reverse=True)

    # Top 4 cells with the highest charge go to active group
    active_group = sorted_cells[:4]

    # Remaining 4 cells go to resting group
    resting_group = sorted_cells[4:]

    return active_group, resting_group

def display_battery_status(cycle_distance):
    """Print the current battery status of all cells and distance covered."""
    status = " | ".join(f"Cell {i+1}: {battery_pack[i]:.1f}%" for i in range(8))
    print(f"[Battery Status] {status}")
    print(f"[Distance Covered] {cycle_distance:.2f} km in this cycle.")

# Simulation loop
total_distance = 0
for cycle in range(1, 11):  # Run 10 cycles for simulation
    print(f"\n[Cycle {cycle}]")

    # Distance covered in this cycle
    cycle_distance = current_range_factor
    total_distance += cycle_distance

    display_battery_status(cycle_distance)

    # Dynamically select active and resting groups
    active_group, resting_group = select_groups()
    print(f"Selected Active Group: {[i+1 for i in active_group]}")
    print(f"Selected Resting Group: {[i+1 for i in resting_group]}")

    # Discharge active group and charge resting group
    print("Discharging active group and charging resting group...")
    discharge_group(active_group)
    charge_group(resting_group)

    # Short delay to simulate real-time processing (remove for faster testing)
    time.sleep(1)

print("\n[Final Battery Status and Total Distance]")
display_battery_status(0)
print(f"Total Distance Covered: {total_distance:.2f} km")
# Out:
# [Cycle 1]
# [Battery Status] Cell 1: 95.9% | Cell 2: 91.5% | Cell 3: 86.4% | Cell 4: 86.1% | Cell 5: 84.0% | Cell 6: 90.1% | Cell 7: 90.3% | Cell 8: 86.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [1, 2, 7, 6]
# Selected Resting Group: [3, 4, 8, 5]
# Discharging active group and charging resting group...
#
# [Cycle 2]
# [Battery Status] Cell 1: 85.9% | Cell 2: 81.5% | Cell 3: 91.4% | Cell 4: 91.1% | Cell 5: 89.0% | Cell 6: 80.1% | Cell 7: 80.3% | Cell 8: 91.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [3, 4, 8, 5]
# Selected Resting Group: [1, 2, 7, 6]
# Discharging active group and charging resting group...
#
# [Cycle 3]
# [Battery Status] Cell 1: 90.9% | Cell 2: 86.5% | Cell 3: 81.4% | Cell 4: 81.1% | Cell 5: 79.0% | Cell 6: 85.1% | Cell 7: 85.3% | Cell 8: 81.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [1, 2, 7, 6]
# Selected Resting Group: [3, 4, 8, 5]
# Discharging active group and charging resting group...
#
# [Cycle 4]
# [Battery Status] Cell 1: 80.9% | Cell 2: 76.5% | Cell 3: 86.4% | Cell 4: 86.1% | Cell 5: 84.0% | Cell 6: 75.1% | Cell 7: 75.3% | Cell 8: 86.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [3, 4, 8, 5]
# Selected Resting Group: [1, 2, 7, 6]
# Discharging active group and charging resting group...
#
# [Cycle 5]
# [Battery Status] Cell 1: 85.9% | Cell 2: 81.5% | Cell 3: 76.4% | Cell 4: 76.1% | Cell 5: 74.0% | Cell 6: 80.1% | Cell 7: 80.3% | Cell 8: 76.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [1, 2, 7, 6]
# Selected Resting Group: [3, 4, 8, 5]
# Discharging active group and charging resting group...
#
# [Cycle 6]
# [Battery Status] Cell 1: 75.9% | Cell 2: 71.5% | Cell 3: 81.4% | Cell 4: 81.1% | Cell 5: 79.0% | Cell 6: 70.1% | Cell 7: 70.3% | Cell 8: 81.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [3, 4, 8, 5]
# Selected Resting Group: [1, 2, 7, 6]
# Discharging active group and charging resting group...
#
# [Cycle 7]
# [Battery Status] Cell 1: 80.9% | Cell 2: 76.5% | Cell 3: 71.4% | Cell 4: 71.1% | Cell 5: 69.0% | Cell 6: 75.1% | Cell 7: 75.3% | Cell 8: 71.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [1, 2, 7, 6]
# Selected Resting Group: [3, 4, 8, 5]
# Discharging active group and charging resting group...
#
# [Cycle 8]
# [Battery Status] Cell 1: 70.9% | Cell 2: 66.5% | Cell 3: 76.4% | Cell 4: 76.1% | Cell 5: 74.0% | Cell 6: 65.1% | Cell 7: 65.3% | Cell 8: 76.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [3, 4, 8, 5]
# Selected Resting Group: [1, 2, 7, 6]
# Discharging active group and charging resting group...
#
# [Cycle 9]
# [Battery Status] Cell 1: 75.9% | Cell 2: 71.5% | Cell 3: 66.4% | Cell 4: 66.1% | Cell 5: 64.0% | Cell 6: 70.1% | Cell 7: 70.3% | Cell 8: 66.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [1, 2, 7, 6]
# Selected Resting Group: [3, 4, 8, 5]
# Discharging active group and charging resting group...
#
# [Cycle 10]
# [Battery Status] Cell 1: 65.9% | Cell 2: 61.5% | Cell 3: 71.4% | Cell 4: 71.1% | Cell 5: 69.0% | Cell 6: 60.1% | Cell 7: 60.3% | Cell 8: 71.0%
# [Distance Covered] 1.00 km in this cycle.
# Selected Active Group: [3, 4, 8, 5]
# Selected Resting Group: [1, 2, 7, 6]
# Discharging active group and charging resting group...
#
# [Final Battery Status and Total Distance]
# [Battery Status] Cell 1: 70.9% | Cell 2: 66.5% | Cell 3: 61.4% | Cell 4: 61.1% | Cell 5: 59.0% | Cell 6: 65.1% | Cell 7: 65.3% | Cell 8: 61.0%
# [Distance Covered] 0.00 km in this cycle.
# Total Distance Covered: 10.00 km

# %%
import random
import time

# Initialize battery pack with 8 cells, each with a charge level between 80-100%
battery_pack = [random.uniform(80, 100) for _ in range(8)]
min_charge = 20        # Minimum charge threshold to trigger group reshuffling
charge_rate = 5        # Charge rate per cycle
base_discharge_rate = 10  # Base discharge rate per cycle

# Define distance ranges and adjust discharge rates based on driving conditions
distance_ranges = {
    'city': (0.5, 1.5),      # Short distance per cycle (e.g., city driving)
    'highway': (1.5, 3.0),   # Moderate distance per cycle (e.g., highway driving)
    'uphill': (0.3, 1.0)     # Short distance, high drain (e.g., uphill driving)
}

def get_cycle_distance():
    """Randomly select a driving condition and return distance and adjusted discharge rate."""
    condition = random.choice(list(distance_ranges.keys()))
    distance = random.uniform(*distance_ranges[condition])
    adjusted_discharge_rate = base_discharge_rate * (distance / 1.5)  # Increase drain with distance
    return distance, adjusted_discharge_rate, condition

def discharge_group(group, discharge_rate):
    """Discharge the active group cells based on the adjusted discharge rate."""
    for i in group:
        battery_pack[i] = max(0, battery_pack[i] - discharge_rate)

def charge_group(group):
    """Charge the resting group cells."""
    for i in group:
        battery_pack[i] = min(100, battery_pack[i] + charge_rate)

def select_groups():
    """Select cells dynamically based on current charge levels."""
    # Sort cells by charge level (descending) and get their indices
    sorted_cells = sorted(range(len(battery_pack)), key=lambda i: battery_pack[i], reverse=True)

    # Top 4 cells with the highest charge go to active group
    active_group = sorted_cells[:4]

    # Remaining 4 cells go to resting group
    resting_group = sorted_cells[4:]

    return active_group, resting_group

def display_battery_status(cycle_distance, condition):
    """Print the current battery status of all cells and distance covered."""
    status = " | ".join(f"Cell {i+1}: {battery_pack[i]:.1f}%" for i in range(8))
    print(f"[Battery Status] {status}")
    print(f"[Condition: {condition.capitalize()}] Distance Covered: {cycle_distance:.2f} km in this cycle.")

# Simulation loop
total_distance = 0
for cycle in range(1, 11):  # Run 10 cycles for simulation
    print(f"\n[Cycle {cycle}]")

    # Get distance and adjusted discharge rate for this cycle
    cycle_distance, discharge_rate, condition = get_cycle_distance()
    total_distance += cycle_distance

    display_battery_status(cycle_distance, condition)

    # Dynamically select active and resting groups
    active_group, resting_group = select_groups()
    print(f"Selected Active Group: {[i+1 for i in active_group]}")
    print(f"Selected Resting Group: {[i+1 for i in resting_group]}")

    # Discharge active group and charge resting group
    print("Discharging active group and charging resting group...")
    discharge_group(active_group, discharge_rate)
    charge_group(resting_group)

    # Short delay to simulate real-time processing (remove for faster testing)
    time.sleep(1)

print("\n[Final Battery Status and Total Distance]")
display_battery_status(0, "Final")
print(f"Total Distance Covered: {total_distance:.2f} km")
# Out:
# [Cycle 1]
# [Battery Status] Cell 1: 87.7% | Cell 2: 95.7% | Cell 3: 82.7% | Cell 4: 93.8% | Cell 5: 97.0% | Cell 6: 97.1% | Cell 7: 83.0% | Cell 8: 87.1%
# [Condition: Highway] Distance Covered: 2.98 km in this cycle.
# Selected Active Group: [6, 5, 2, 4]
# Selected Resting Group: [1, 8, 7, 3]
# Discharging active group and charging resting group...
#
# [Cycle 2]
# [Battery Status] Cell 1: 92.7% | Cell 2: 75.8% | Cell 3: 87.7% | Cell 4: 73.9% | Cell 5: 77.1% | Cell 6: 77.2% | Cell 7: 88.0% | Cell 8: 92.1%
# [Condition: Uphill] Distance Covered: 0.69 km in this cycle.
# Selected Active Group: [1, 8, 7, 3]
# Selected Resting Group: [6, 5, 2, 4]
# Discharging active group and charging resting group...
#
# [Cycle 3]
# [Battery Status] Cell 1: 88.1% | Cell 2: 80.8% | Cell 3: 83.1% | Cell 4: 78.9% | Cell 5: 82.1% | Cell 6: 82.2% | Cell 7: 83.4% | Cell 8: 87.5%
# [Condition: Highway] Distance Covered: 2.30 km in this cycle.
# Selected Active Group: [1, 8, 7, 3]
# Selected Resting Group: [6, 5, 2, 4]
# Discharging active group and charging resting group...
#
# [Cycle 4]
# [Battery Status] Cell 1: 72.7% | Cell 2: 85.8% | Cell 3: 67.7% | Cell 4: 83.9% | Cell 5: 87.1% | Cell 6: 87.2% | Cell 7: 68.0% | Cell 8: 72.1%
# [Condition: Highway] Distance Covered: 2.97 km in this cycle.
# Selected Active Group: [6, 5, 2, 4]
# Selected Resting Group: [1, 8, 7, 3]
# Discharging active group and charging resting group...
#
# [Cycle 5]
# [Battery Status] Cell 1: 77.7% | Cell 2: 66.0% | Cell 3: 72.7% | Cell 4: 64.1% | Cell 5: 67.3% | Cell 6: 67.5% | Cell 7: 73.0% | Cell 8: 77.1%
# [Condition: City] Distance Covered: 1.31 km in this cycle.
# Selected Active Group: [1, 8, 7, 3]
# Selected Resting Group: [6, 5, 2, 4]
# Discharging active group and charging resting group...
#
# [Cycle 6]
# [Battery Status] Cell 1: 69.0% | Cell 2: 71.0% | Cell 3: 64.0% | Cell 4: 69.1% | Cell 5: 72.3% | Cell 6: 72.5% | Cell 7: 64.3% | Cell 8: 68.4%
# [Condition: Uphill] Distance Covered: 0.85 km in this cycle.
# Selected Active Group: [6, 5, 2, 4]
# Selected Resting Group: [1, 8, 7, 3]
# Discharging active group and charging resting group...
#
# [Cycle 7]
# [Battery Status] Cell 1: 74.0% | Cell 2: 65.3% | Cell 3: 69.0% | Cell 4: 63.4% | Cell 5: 66.6% | Cell 6: 66.8% | Cell 7: 69.3% | Cell 8: 73.4%
# [Condition: Highway] Distance Covered: 2.81 km in this cycle.
# Selected Active Group: [1, 8, 7, 3]
# Selected Resting Group: [6, 5, 2, 4]
# Discharging active group and charging resting group...
#
# [Cycle 8]
# [Battery Status] Cell 1: 55.3% | Cell 2: 70.3% | Cell 3: 50.3% | Cell 4: 68.4% | Cell 5: 71.6% | Cell 6: 71.8% | Cell 7: 50.6% | Cell 8: 54.7%
# [Condition: Uphill] Distance Covered: 0.43 km in this cycle.
# Selected Active Group: [6, 5, 2, 4]
# Selected Resting Group: [1, 8, 7, 3]
# Discharging active group and charging resting group...
#
# [Cycle 9]
# [Battery Status] Cell 1: 60.3% | Cell 2: 67.4% | Cell 3: 55.3% | Cell 4: 65.6% | Cell 5: 68.8% | Cell 6: 68.9% | Cell 7: 55.6% | Cell 8: 59.7%
# [Condition: Highway] Distance Covered: 1.58 km in this cycle.
# Selected Active Group: [6, 5, 2, 4]
# Selected Resting Group: [1, 8, 7, 3]
# Discharging active group and charging resting group...
#
# [Cycle 10]
# [Battery Status] Cell 1: 65.3% | Cell 2: 56.9% | Cell 3: 60.3% | Cell 4: 55.0% | Cell 5: 58.3% | Cell 6: 58.4% | Cell 7: 60.6% | Cell 8: 64.7%
# [Condition: City] Distance Covered: 0.98 km in this cycle.
# Selected Active Group: [1, 8, 7, 3]
# Selected Resting Group: [6, 5, 2, 4]
# Discharging active group and charging resting group...
#
# [Final Battery Status and Total Distance]
# [Battery Status] Cell 1: 58.8% | Cell 2: 61.9% | Cell 3: 53.8% | Cell 4: 60.0% | Cell 5: 63.3% | Cell 6: 63.4% | Cell 7: 54.1% | Cell 8: 58.2%
# [Condition: Final] Distance Covered: 0.00 km in this cycle.
# Total Distance Covered: 16.90 km
