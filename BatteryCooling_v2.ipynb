# %% [markdown]
# <a href="https://colab.research.google.com/github/Perfect-Cube/Volkswagon-imobilothon-4.0/blob/main/BatteryCooling_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

# Larger simulated dataset for Indian climate and driving conditions
data = pd.DataFrame({
    'route': np.random.choice(['urban', 'highway', 'hilly', 'coastal'], size=5000),
    'ambient_temp': np.random.uniform(10, 50, size=5000),  # Expanded to cover high temperatures in India
    'speed': np.random.uniform(0, 120, size=5000),
    'motor_workload': np.random.uniform(0, 1, size=5000),
    'battery_temp': np.random.uniform(20, 80, size=5000)
})

# Encode routes for different Indian regions
data = pd.get_dummies(data, columns=['route'])

# Scale features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(data[['ambient_temp', 'speed', 'motor_workload', 'battery_temp']])

# Define Variational Autoencoder (VAE) for dynamic cooling prediction
latent_dim = 2
inputs = Input(shape=(scaled_features.shape[1],))
h = Dense(64, activation='relu')(inputs)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

# Sampling function using Keras Lambda layer
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_var / 2) * epsilon

z = Lambda(sampling)([z_mean, z_log_var])

# Decoder part
decoder_h = Dense(64, activation='relu')
decoder_mean = Dense(scaled_features.shape[1])  # Output back to original feature size (4)
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# Define a custom VAE loss layer
class VAELossLayer(Layer):
    def call(self, inputs, **kwargs):
        x = inputs[0]
        x_decoded_mean = inputs[1]
        z_mean = inputs[2]
        z_log_var = inputs[3]

        reconstruction_loss = tf.reduce_mean(tf.square(x - x_decoded_mean))
        kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        vae_loss = K.mean(reconstruction_loss + kl_loss)

        self.add_loss(vae_loss)
        return x_decoded_mean

# Apply the custom loss layer
outputs = VAELossLayer()([inputs, x_decoded_mean, z_mean, z_log_var])
vae = Model(inputs, outputs)

# Compile and train the VAE
vae.compile(optimizer='adam')
vae.fit(scaled_features, scaled_features, epochs=50, batch_size=64, validation_split=0.2)

# Cooling methods
def air_cooling():
    print("Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.")

def fan_cooling():
    print("Fan cooling: Ideal for higher loads in variable Indian climates.")

def liquid_cooling():
    print("Liquid cooling: Optimal for high-performance needs in extreme heat conditions.")

# Cooling selection logic for Indian conditions
def select_cooling_method(predicted_temp_increase, ambient_temp, speed, route):
    """
    Selects cooling method based on predicted temperature and conditions for Indian environments.
    """
    if predicted_temp_increase > 70 or (ambient_temp > 40 and route in ['hilly', 'urban']):
        liquid_cooling()
    elif predicted_temp_increase > 50 or (ambient_temp > 30 and speed > 80):
        fan_cooling()
    else:
        air_cooling()

# Scenario generation with Indian standards
def generate_cooling_scenario(input_data):
    # Prepare input data similar to training data
    input_df = pd.DataFrame([input_data])  # Create a DataFrame from the input dictionary
    input_df = pd.get_dummies(input_df, columns=['route'])  # One-hot encode route

    # Ensure all columns from training data are present in input_df
    missing_cols = set(data.columns) - set(input_df.columns)
    for col in missing_cols:
        input_df[col] = 0  # Add missing columns with 0 values

    # Scale the input data using the same scaler
    scaled_input = scaler.transform(input_df[['ambient_temp', 'speed', 'motor_workload', 'battery_temp']])

    # Now use the scaled input for prediction
    generated_data = vae.predict(scaled_input)
    predicted_temp_increase = generated_data[0, -1]

# Example input for Indian scenario
input_data_example = {'ambient_temp': 42, 'speed': 90, 'route': 'hilly'}
generate_cooling_scenario(input_data_example)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 1.0104 - val_loss: 0.8668
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7985 - val_loss: 0.6944
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6690 - val_loss: 0.6542
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6393 - val_loss: 0.6515
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6339 - val_loss: 0.6490
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6347 - val_loss: 0.6468
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6343 - val_loss: 0.6489
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6365 - val_loss: 0.6423
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6261 - val_loss: 0.6435
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6335 - val_loss: 0.6414
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6218 - val_loss: 0.6438
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6149 - val_loss: 0.6345
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6054 - val_loss: 0.6331
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6097 - val_loss: 0.6259
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6130 - val_loss: 0.6186
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6033 - val_loss: 0.6158
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5880 - val_loss: 0.6086
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5910 - val_loss: 0.6111
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5784 - val_loss: 0.5992
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5781 - val_loss: 0.6024
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5746 - val_loss: 0.5941
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5626 - val_loss: 0.5921
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5625 - val_loss: 0.5776
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5622 - val_loss: 0.5807
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5604 - val_loss: 0.5751
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5634 - val_loss: 0.5746
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5517 - val_loss: 0.5593
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5486 - val_loss: 0.5588
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5328 - val_loss: 0.5537
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5410 - val_loss: 0.5529
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5327 - val_loss: 0.5494
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5316 - val_loss: 0.5358
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5229 - val_loss: 0.5463
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5181 - val_loss: 0.5309
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5140 - val_loss: 0.5339
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5092 - val_loss: 0.5224
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5143 - val_loss: 0.5256
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5097 - val_loss: 0.5282
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4993 - val_loss: 0.5225
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4931 - val_loss: 0.5294
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4936 - val_loss: 0.5261
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4961 - val_loss: 0.5190
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4916 - val_loss: 0.5064
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4889 - val_loss: 0.5066
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4962 - val_loss: 0.5163
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4890 - val_loss: 0.5080
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4869 - val_loss: 0.5025
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4985 - val_loss: 0.5063
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4788 - val_loss: 0.5035
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4943 - val_loss: 0.4990
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import random

# Larger simulated dataset for Indian climate and driving conditions
data = pd.DataFrame({
    'route': np.random.choice(['urban', 'highway', 'hilly', 'coastal'], size=5000),
    'ambient_temp': np.random.uniform(10, 50, size=5000),  # Expanded to cover high temperatures in India
    'speed': np.random.uniform(0, 120, size=5000),
    'motor_workload': np.random.uniform(0, 1, size=5000),
    'battery_temp': np.random.uniform(20, 80, size=5000)
})

# Encode routes for different Indian regions
data = pd.get_dummies(data, columns=['route'])

# Scale features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(data[['ambient_temp', 'speed', 'motor_workload', 'battery_temp']])

# Define Variational Autoencoder (VAE) for dynamic cooling prediction
latent_dim = 2
inputs = Input(shape=(scaled_features.shape[1],))
h = Dense(64, activation='relu')(inputs)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

# Sampling function using Keras Lambda layer
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_var / 2) * epsilon

z = Lambda(sampling)([z_mean, z_log_var])

# Decoder part
decoder_h = Dense(64, activation='relu')
decoder_mean = Dense(scaled_features.shape[1])  # Output back to original feature size (4)
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# Define a custom VAE loss layer
class VAELossLayer(Layer):
    def call(self, inputs, **kwargs):
        x = inputs[0]
        x_decoded_mean = inputs[1]
        z_mean = inputs[2]
        z_log_var = inputs[3]

        reconstruction_loss = tf.reduce_mean(tf.square(x - x_decoded_mean))
        kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        vae_loss = K.mean(reconstruction_loss + kl_loss)

        self.add_loss(vae_loss)
        return x_decoded_mean

# Apply the custom loss layer
outputs = VAELossLayer()([inputs, x_decoded_mean, z_mean, z_log_var])
vae = Model(inputs, outputs)

# Compile and train the VAE
vae.compile(optimizer='adam')
vae.fit(scaled_features, scaled_features, epochs=50, batch_size=64, validation_split=0.2)

# Cooling methods
def air_cooling():
    print("Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.")

def fan_cooling():
    print("Fan cooling: Ideal for higher loads in variable Indian climates.")

def liquid_cooling():
    print("Liquid cooling: Optimal for high-performance needs in extreme heat conditions.")

# Cooling selection logic for Indian conditions
def select_cooling_method(predicted_temp_increase, ambient_temp, speed, route):
    """
    Selects cooling method based on predicted temperature and conditions for Indian environments.
    """
    if predicted_temp_increase > 70 or (ambient_temp > 40 and route in ['hilly', 'urban']):
        liquid_cooling()
    elif predicted_temp_increase > 50 or (ambient_temp > 30 and speed > 80):
        fan_cooling()
    else:
        air_cooling()

# Scenario generation with Indian standards
def generate_cooling_scenario(input_data):
    # Prepare input data similar to training data
    input_df = pd.DataFrame([input_data])  # Create a DataFrame from the input dictionary
    input_df = pd.get_dummies(input_df, columns=['route'])  # One-hot encode route

    # Ensure all columns from training data are present in input_df
    missing_cols = set(data.columns) - set(input_df.columns)
    for col in missing_cols:
        input_df[col] = 0  # Add missing columns with 0 values

    # Scale the input data using the same scaler
    scaled_input = scaler.transform(input_df[['ambient_temp', 'speed', 'motor_workload', 'battery_temp']])

    # Now use the scaled input for prediction
    generated_data = vae.predict(scaled_input)
    predicted_temp_increase = generated_data[0, -1]

    # Cooling method selection
    select_cooling_method(predicted_temp_increase, input_data['ambient_temp'], input_data['speed'], input_data['route'])

# Simulate EV cooling system for a one-day period
def simulate_one_day():
    # Generate random driving conditions over 24 hours
    time_steps = 24 * 60  # Assuming 1-minute intervals for a day
    for _ in range(time_steps):
        input_data = {
            'ambient_temp': random.uniform(10, 50),
            'speed': random.uniform(0, 120),
            'motor_workload': random.uniform(0, 1),
            'route': random.choice(['urban', 'highway', 'hilly', 'coastal'])
        }
        print(f"Time step: {_} - Driving condition: {input_data}")
        generate_cooling_scenario(input_data)

# Run the one-day simulation
simulate_one_day()
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 57s 48ms/step - loss: 1.0910 - val_loss: 0.8801
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8356 - val_loss: 0.6794
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6742 - val_loss: 0.6353
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6395 - val_loss: 0.6273
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6412 - val_loss: 0.6206
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6227 - val_loss: 0.6187
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6209 - val_loss: 0.6171
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6181 - val_loss: 0.6163
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6118 - val_loss: 0.6115
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6115 - val_loss: 0.6095
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6166 - val_loss: 0.6044
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6108 - val_loss: 0.6006
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5967 - val_loss: 0.5917
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5922 - val_loss: 0.5922
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5931 - val_loss: 0.5823
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5893 - val_loss: 0.5776
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5764 - val_loss: 0.5721
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5778 - val_loss: 0.5711
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5674 - val_loss: 0.5765
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5704 - val_loss: 0.5645
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5655 - val_loss: 0.5647
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1392 - Driving condition: {'ambient_temp': 43.9030091740368, 'speed': 96.0259736398591, 'motor_workload': 0.8174246866587116, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1393 - Driving condition: {'ambient_temp': 49.21147100695305, 'speed': 80.4576401768363, 'motor_workload': 0.1035568461054377, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1394 - Driving condition: {'ambient_temp': 49.12166143657546, 'speed': 73.63326422923429, 'motor_workload': 0.005425399658564367, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1395 - Driving condition: {'ambient_temp': 20.585819160544094, 'speed': 15.844717919615503, 'motor_workload': 0.8243121974234208, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1396 - Driving condition: {'ambient_temp': 48.45718655053366, 'speed': 14.472702328177007, 'motor_workload': 0.4547991427672835, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1397 - Driving condition: {'ambient_temp': 35.03274503200508, 'speed': 10.792028860297602, 'motor_workload': 0.9667473442233524, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1398 - Driving condition: {'ambient_temp': 31.615397136739848, 'speed': 92.05733031428194, 'motor_workload': 0.46615251518661893, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1399 - Driving condition: {'ambient_temp': 13.816257638787302, 'speed': 58.18943283762825, 'motor_workload': 0.4925582560083104, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1400 - Driving condition: {'ambient_temp': 21.806492410971465, 'speed': 93.15390385483235, 'motor_workload': 0.9631801330793451, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1401 - Driving condition: {'ambient_temp': 37.984553020982354, 'speed': 89.60355305332752, 'motor_workload': 0.8012286247278831, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1402 - Driving condition: {'ambient_temp': 19.997111174974584, 'speed': 93.55643363144021, 'motor_workload': 0.7583797460814798, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1403 - Driving condition: {'ambient_temp': 25.38467967544758, 'speed': 31.15181725977701, 'motor_workload': 0.6337185483253523, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1404 - Driving condition: {'ambient_temp': 15.806327396370467, 'speed': 91.6141709457855, 'motor_workload': 0.37672337573092785, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1405 - Driving condition: {'ambient_temp': 18.617961134882762, 'speed': 108.87064434467526, 'motor_workload': 0.08485110055284617, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1406 - Driving condition: {'ambient_temp': 17.542782315547978, 'speed': 90.98312219233814, 'motor_workload': 0.19205719362858942, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1407 - Driving condition: {'ambient_temp': 44.536234147008344, 'speed': 89.16083693204962, 'motor_workload': 0.9073526727050639, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1408 - Driving condition: {'ambient_temp': 11.837914826535872, 'speed': 87.64365786601284, 'motor_workload': 0.6023419737737513, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1409 - Driving condition: {'ambient_temp': 16.956923382308688, 'speed': 7.947277519783804, 'motor_workload': 0.03761969683460287, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1410 - Driving condition: {'ambient_temp': 14.090620439481008, 'speed': 112.95801563967154, 'motor_workload': 0.7925850949312272, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1411 - Driving condition: {'ambient_temp': 28.289178699308266, 'speed': 115.45430150217202, 'motor_workload': 0.5188270538466144, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1412 - Driving condition: {'ambient_temp': 25.76234591646678, 'speed': 95.60697202248475, 'motor_workload': 0.7780125203354982, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1413 - Driving condition: {'ambient_temp': 30.487060458487658, 'speed': 37.28707139734015, 'motor_workload': 0.6288012202340049, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1414 - Driving condition: {'ambient_temp': 44.90506572111172, 'speed': 57.44144395115442, 'motor_workload': 0.6999499449904526, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Liquid cooling: Optimal for high-performance needs in extreme heat conditions.
# Time step: 1415 - Driving condition: {'ambient_temp': 32.8727985903632, 'speed': 15.786267127476732, 'motor_workload': 0.9475231013065042, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1416 - Driving condition: {'ambient_temp': 29.47443866391702, 'speed': 28.02453470205064, 'motor_workload': 0.37764586573545744, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1417 - Driving condition: {'ambient_temp': 18.317760941003066, 'speed': 106.57365744046388, 'motor_workload': 0.4576211703764781, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1418 - Driving condition: {'ambient_temp': 16.720083390082245, 'speed': 118.97018677393334, 'motor_workload': 0.28707073623056767, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1419 - Driving condition: {'ambient_temp': 38.92849775218748, 'speed': 17.0525115486563, 'motor_workload': 0.8572738116463562, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1420 - Driving condition: {'ambient_temp': 38.630784362173614, 'speed': 97.03837393570517, 'motor_workload': 0.9128858637118733, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1421 - Driving condition: {'ambient_temp': 43.36715465779177, 'speed': 41.27850721278682, 'motor_workload': 0.22452345166029253, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1422 - Driving condition: {'ambient_temp': 26.355386325012194, 'speed': 32.187514086182965, 'motor_workload': 0.7992065453219744, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1423 - Driving condition: {'ambient_temp': 32.66568213723221, 'speed': 107.89786492243749, 'motor_workload': 0.2833228426174794, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1424 - Driving condition: {'ambient_temp': 27.291511964756342, 'speed': 1.529844655088417, 'motor_workload': 0.6074352410887967, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1425 - Driving condition: {'ambient_temp': 34.087050395334025, 'speed': 28.95276993447894, 'motor_workload': 0.7252657265392322, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1426 - Driving condition: {'ambient_temp': 43.4288895680085, 'speed': 98.01904541269886, 'motor_workload': 0.2583555736660169, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1427 - Driving condition: {'ambient_temp': 16.176712877176126, 'speed': 53.0919414620756, 'motor_workload': 0.4414040201946201, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1428 - Driving condition: {'ambient_temp': 26.009823373322018, 'speed': 6.32050013552274, 'motor_workload': 0.3383982141960711, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1429 - Driving condition: {'ambient_temp': 28.180944250285886, 'speed': 29.97974806915783, 'motor_workload': 0.7706081122573858, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1430 - Driving condition: {'ambient_temp': 43.87533503932511, 'speed': 74.52699632108755, 'motor_workload': 0.13890768357394445, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1431 - Driving condition: {'ambient_temp': 27.087204873622408, 'speed': 105.09791705137924, 'motor_workload': 0.8357783403327952, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1432 - Driving condition: {'ambient_temp': 23.230910057116034, 'speed': 97.07335590156968, 'motor_workload': 0.010323693235236298, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1433 - Driving condition: {'ambient_temp': 27.83627339488809, 'speed': 2.0603572093268907, 'motor_workload': 0.2652394270639733, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1434 - Driving condition: {'ambient_temp': 31.129122040298945, 'speed': 82.96316953093225, 'motor_workload': 0.8817980443712269, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Fan cooling: Ideal for higher loads in variable Indian climates.
# Time step: 1435 - Driving condition: {'ambient_temp': 33.59654871412035, 'speed': 21.504773915780852, 'motor_workload': 0.8947530809019937, 'route': 'highway'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1436 - Driving condition: {'ambient_temp': 14.514948694165053, 'speed': 81.18832617261008, 'motor_workload': 0.9831136644182434, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1437 - Driving condition: {'ambient_temp': 33.13981199392785, 'speed': 40.80989365008901, 'motor_workload': 0.9492629805313934, 'route': 'coastal'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1438 - Driving condition: {'ambient_temp': 18.509898133637254, 'speed': 33.92187795829602, 'motor_workload': 0.4627387965233172, 'route': 'hilly'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
# Time step: 1439 - Driving condition: {'ambient_temp': 11.10321108272229, 'speed': 85.06675118673424, 'motor_workload': 0.38005982134580407, 'route': 'urban'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Air cooling: Suitable for mild loads, typically in urban areas or moderate climates.
